# %% [markdown]
# <a href="https://colab.research.google.com/github/manjari-cse/Image-processing/blob/main/data_set_rendering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
b = np.load('/demo-data-50-50-20.npy', allow_pickle=True)
print(np.size(b))
for i in range(20):
  for j in range(20):
    for k in range(20):
      plt.imshow(b[i][j][k])
      plt.show()
# Out:
# 300
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-a53956cf15b1> in <module>()
#       6   for j in range(20):
#       7     for k in range(20):
# ----> 8       plt.imshow(b[i][j][k])
#       9       plt.show()
#      10
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2682         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2683         resample=resample, url=url, **({"data": data} if data is not
# -> 2684         None else {}), **kwargs)
#    2685     sci(__ret)
#    2686     return __ret
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1597     def inner(ax, *args, data=None, **kwargs):
# ...
